# %%
import numpy as np
import pandas as pd
import pandas_datareader as web

from collections import Counter
import pickle

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# %run functions.ipynb

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler, scale
from sklearn.pipeline import Pipeline

#Import models
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
import tensorflow as tf
from tensorflow import keras

# %%
tickers = ['SPY','QQQ','AAPL','MSFT']
start = '2008/01/01'
end = '2018/12/31'

# %%
main_df = create_df(tickers, start, end, days_to_predict=5)

# %%
main_df.head()
# Out:
#             EMA12_pctchg        RSI   Pct_Chg  MACD_sentiment  \
# Date
# 2008-02-07      1.085848  40.966392  0.661398               1
# 2008-02-08      1.457182  39.314111 -0.642116               1
# 2008-02-11      0.806730  41.319177  0.511004               1
# 2008-02-12      0.095374  44.877554  0.927107               1
# 2008-02-13      0.943752  48.594457  1.022290               0
#
#             Upper_BB_pctchg  Lower_BB_pctchg  EMA_sentiment  Volume_sentiment  \
# Date
# 2008-02-07         5.707755         3.218491              0                 0
# 2008-02-08         5.751686         2.536537              0                 1
# 2008-02-11         4.786109         2.998865              0                 1
# 2008-02-12         3.101548         3.528514              0                 0
# 2008-02-13         1.896489         4.487057              0                 1
#
#             bull_target  bear_target
# Date
# 2008-02-07            1            0
# 2008-02-08            1            0
# 2008-02-11            1            0
# 2008-02-12            1            0
# 2008-02-13            0            1

# %%
alternative_data = pd.read_csv('data/cleaned_alternative_data.csv', index_col='index')
alternative_data.drop('Unnamed: 0', axis=1, inplace=True)

# %%
alternative_data.shape
# Out:
# (3528, 9)

# %%
full_df = alternative_data.join(main_df)

# %%
full_df.head(3)
# Out:
#              Returns  Unemployment Rate  Inflation Rate  Misery Index  \
# 2010-09-30  1.596909                0.0       -0.008696      -0.00093
# 2010-09-30  1.596909                0.0       -0.008696      -0.00093
# 2010-09-30  1.596909                0.0       -0.008696      -0.00093
#
#             local_price   Bullish   Neutral   Bearish  Bull-Bear Spread  \
# 2010-09-30     0.042831 -0.054258 -0.127236  0.244488         -0.442003
# 2010-09-30     0.042831 -0.054258 -0.127236  0.244488         -0.442003
# 2010-09-30     0.042831 -0.054258 -0.127236  0.244488         -0.442003
#
#             EMA12_pctchg        RSI   Pct_Chg  MACD_sentiment  \
# 2010-09-30     -0.618518  59.713065 -0.297025             0.0
# 2010-09-30     -0.091104  67.168690 -0.446340             0.0
# 2010-09-30     -0.668003  64.989092 -1.259701             0.0
#
#             Upper_BB_pctchg  Lower_BB_pctchg  EMA_sentiment  Volume_sentiment  \
# 2010-09-30         1.635451         4.419573            1.0               0.0
# 2010-09-30         2.988150         8.897915            1.0               0.0
# 2010-09-30         5.560850        13.683717            1.0               0.0
#
#             bull_target  bear_target
# 2010-09-30          1.0          0.0
# 2010-09-30          1.0          0.0
# 2010-09-30          1.0          0.0

# %%
full_df.tail(3)
# Out:
#              Returns  Unemployment Rate  Inflation Rate  Misery Index  \
# 2018-12-31 -1.067037           0.054054       -0.123853     -0.011905
# 2018-12-31 -1.067037           0.054054       -0.123853     -0.011905
# 2018-12-31 -1.067037           0.054054       -0.123853     -0.011905
#
#             local_price  Bullish   Neutral   Bearish  Bull-Bear Spread  \
# 2018-12-31     0.043561  0.26876 -0.347836  0.063435         -0.164155
# 2018-12-31     0.043561  0.26876 -0.347836  0.063435         -0.164155
# 2018-12-31     0.043561  0.26876 -0.347836  0.063435         -0.164155
#
#             EMA12_pctchg        RSI   Pct_Chg  MACD_sentiment  \
# 2018-12-31     -1.484592  43.037151  0.843298             1.0
# 2018-12-31      0.109512  37.553938  0.966530             0.0
# 2018-12-31     -1.060629  45.277776  1.175416             1.0
#
#             Upper_BB_pctchg  Lower_BB_pctchg  EMA_sentiment  Volume_sentiment  \
# 2018-12-31        11.422266         7.232311            0.0               1.0
# 2018-12-31        14.470893         8.385891            0.0               1.0
# 2018-12-31        11.008870         6.576955            0.0               1.0
#
#             bull_target  bear_target
# 2018-12-31          0.0          0.0
# 2018-12-31          0.0          0.0
# 2018-12-31          0.0          0.0

# %%
full_df.sample(3)
# Out:
#              Returns  Unemployment Rate  Inflation Rate  Misery Index  \
# 2019-11-09 -1.536708           0.028571        0.029240      0.028791
# 2010-12-14 -1.341927           0.010309       -0.025641      0.006440
# 2015-10-07 -1.010613           0.000000       -1.200000     -0.045283
#
#             local_price   Bullish   Neutral   Bearish  Bull-Bear Spread  \
# 2019-11-09     0.028674  0.186203 -0.048472 -0.158411          1.954206
# 2010-12-14     0.042831  0.068264  0.010356 -0.139260          0.300213
# 2015-10-07     0.000000 -0.124969 -0.184011  0.391189         -4.447827
#
#             EMA12_pctchg        RSI   Pct_Chg  MACD_sentiment  \
# 2019-11-09           NaN        NaN       NaN             NaN
# 2010-12-14      0.603928  58.652390 -0.429013             0.0
# 2015-10-07      1.594658  53.263009  0.599997             0.0
#
#             Upper_BB_pctchg  Lower_BB_pctchg  EMA_sentiment  Volume_sentiment  \
# 2019-11-09              NaN              NaN            NaN               NaN
# 2010-12-14         2.144747         6.137115            1.0               1.0
# 2015-10-07         2.683925         5.556337            0.0               1.0
#
#             bull_target  bear_target
# 2019-11-09          NaN          NaN
# 2010-12-14          1.0          0.0
# 2015-10-07          1.0          0.0

# %%
full_df.replace([np.inf, -np.inf], np.nan, inplace=True)
full_df.dropna(inplace=True)

# %%
full_df['EMA12_pctchg'] = np.log(full_df['EMA12_pctchg'])
full_df = full_df[(full_df['EMA12_pctchg'] < 3.0) & (full_df['EMA12_pctchg'] > -3.0)]
full_df = full_df[(full_df['Pct_Chg'] < 10.0) & (full_df['Pct_Chg'] > -10.0)]

# %%
full_df.columns
# Out:
# Index(['Returns', 'Unemployment Rate', 'Inflation Rate', 'Misery Index',
#        'local_price', 'Bullish', 'Neutral', 'Bearish', 'Bull-Bear Spread',
#        'EMA12_pctchg', 'RSI', 'Pct_Chg', 'MACD_sentiment', 'Upper_BB_pctchg',
#        'Lower_BB_pctchg', 'EMA_sentiment', 'Volume_sentiment', 'bull_target',
#        'bear_target'],
#       dtype='object')

# %%
full_df['bull_target'].value_counts(1)
# Out:
# 1.0    0.589106
# 0.0    0.410894
# Name: bull_target, dtype: float64

# %%
X = full_df[['Returns','Unemployment Rate',
       'Inflation Rate', 'Misery Index', 'local_price', 'Bullish', 'Neutral',
       'Bearish', 'Bull-Bear Spread', 'EMA12_pctchg', 'RSI', 'Pct_Chg',
       'MACD_sentiment', 'Upper_BB_pctchg', 'Lower_BB_pctchg', 'EMA_sentiment',
       'Volume_sentiment']]

y = full_df['bull_target']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.24, random_state=8)

# %% [markdown]
# ### Support Vector Machine

# %%
# %%time
#Buy Signal 
steps = [('scaler', StandardScaler()),
         ('SVM', SVC(probability=True, class_weight='balanced', ))]
pipeline = Pipeline(steps)
parameters = {'SVM__C':[1, 10, 15, 20],
              'SVM__gamma':[10.0, 5.0, 3.0, 1.0]}

svm_cv = GridSearchCV(pipeline, param_grid= parameters, cv=3)
svm_cv.fit(X_train, y_train)
y_pred = svm_cv.predict(X_test)

# Compute and print metrics
best_hyperparams = svm_cv.best_params_
print(svm_cv)
print('Best Hyperparameters:', best_hyperparams)
buy_accuracy = round(svm_cv.score(X_test, y_test)*100, 2)
print("\n")
print(Counter(y_pred))
print("Accuracy: {}".format(svm_cv.score(X_test, y_test)))
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# GridSearchCV(cv=3, error_score=nan,
#              estimator=Pipeline(memory=None,
#                                 steps=[('scaler',
#                                         StandardScaler(copy=True,
#                                                        with_mean=True,
#                                                        with_std=True)),
#                                        ('SVM',
#                                         SVC(C=1.0, break_ties=False,
#                                             cache_size=200,
#                                             class_weight='balanced', coef0=0.0,
#                                             decision_function_shape='ovr',
#                                             degree=3, gamma='scale',
#                                             kernel='rbf', max_iter=-1,
#                                             probability=True, random_state=None,
#                                             shrinking=True, tol=0.001,
#                                             verbose=False))],
#                                 verbose=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'SVM__C': [1, 10, 15, 20],
#                          'SVM__gamma': [10.0, 5.0, 3.0, 1.0]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)
# Best Hyperparameters: {'SVM__C': 10, 'SVM__gamma': 1.0}
#
#
# Counter({1.0: 1274, 0.0: 656})
# Accuracy: 0.7310880829015544
# [[443 306]
#  [213 968]]
#               precision    recall  f1-score   support
#
#          0.0       0.68      0.59      0.63       749
#          1.0       0.76      0.82      0.79      1181
#
#     accuracy                           0.73      1930
#    macro avg       0.72      0.71      0.71      1930
# weighted avg       0.73      0.73      0.73      1930
#
# Wall time: 5min 18s

# %%
pickling_on = open("models/svm_cv_best.pickle","wb")
pickle.dump(svm_cv.best_estimator_, pickling_on)
pickling_on.close()

# %% [markdown]
# ### Logistic Regression

# %%
#Buy signal
steps = [('scaler', StandardScaler()),
        ('logreg', LogisticRegression(class_weight='balanced',))]

pipeline = Pipeline(steps)
parameters = {'logreg__C':[0.1, 0.3,0.5,1,5,10],
              'logreg__solver':['lbfgs', 'liblinear']
              }

logreg_cv = GridSearchCV(pipeline, param_grid= parameters, cv=3)
logreg_cv.fit(X_train, y_train)
y_pred = logreg_cv.predict(X_test)

# Compute and print metrics
best_hyperparams = logreg_cv.best_params_
print(logreg_cv)
print('Best Hyperparameters:', best_hyperparams)
buy_accuracy = round(logreg_cv.score(X_test, y_test)*100, 2)
print("\n")
print(Counter(y_pred))
print("Accuracy: {}".format(logreg_cv.score(X_test, y_test)))
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# GridSearchCV(cv=3, error_score=nan,
#              estimator=Pipeline(memory=None,
#                                 steps=[('scaler',
#                                         StandardScaler(copy=True,
#                                                        with_mean=True,
#                                                        with_std=True)),
#                                        ('logreg',
#                                         LogisticRegression(C=1.0,
#                                                            class_weight='balanced',
#                                                            dual=False,
#                                                            fit_intercept=True,
#                                                            intercept_scaling=1,
#                                                            l1_ratio=None,
#                                                            max_iter=100,
#                                                            multi_class='auto',
#                                                            n_jobs=None,
#                                                            penalty='l2',
#                                                            random_state=None,
#                                                            solver='lbfgs',
#                                                            tol=0.0001,
#                                                            verbose=0,
#                                                            warm_start=False))],
#                                 verbose=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'logreg__C': [0.1, 0.3, 0.5, 1, 5, 10],
#                          'logreg__solver': ['lbfgs', 'liblinear']},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)
# Best Hyperparameters: {'logreg__C': 0.1, 'logreg__solver': 'liblinear'}
#
#
# Counter({1.0: 1040, 0.0: 890})
# Accuracy: 0.5238341968911917
# [[360 389]
#  [530 651]]
#               precision    recall  f1-score   support
#
#          0.0       0.40      0.48      0.44       749
#          1.0       0.63      0.55      0.59      1181
#
#     accuracy                           0.52      1930
#    macro avg       0.52      0.52      0.51      1930
# weighted avg       0.54      0.52      0.53      1930

# %%
pickling_on = open("models/logreg_cv_best.pickle","wb")
pickle.dump(logreg_cv.best_estimator_, pickling_on)
pickling_on.close()

# %% [markdown]
# ### Random Forests

# %%
#Buy Signal
steps = [('scaler', StandardScaler()),
        ('rf', RandomForestClassifier(class_weight='balanced'))]

pipeline = Pipeline(steps)
parameters = {'rf__n_estimators':[50,100,150,200],
              'rf__max_depth':[2,3,4,5]
              }

rf_cv = GridSearchCV(pipeline, param_grid= parameters, cv=3)
rf_cv.fit(X_train, y_train)
y_pred = rf_cv.predict(X_test)

# Compute and print metrics
best_hyperparams = rf_cv.best_params_
print(rf_cv)
print('Best Hyperparameters:', best_hyperparams)
buy_accuracy = round(rf_cv.score(X_test, y_test)*100, 2)
print("\n")
print(Counter(y_pred))
print("Accuracy: {}".format(rf_cv.score(X_test, y_test)))
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# GridSearchCV(cv=3, error_score=nan,
#              estimator=Pipeline(memory=None,
#                                 steps=[('scaler',
#                                         StandardScaler(copy=True,
#                                                        with_mean=True,
#                                                        with_std=True)),
#                                        ('rf',
#                                         RandomForestClassifier(bootstrap=True,
#                                                                ccp_alpha=0.0,
#                                                                class_weight='balanced',
#                                                                criterion='gini',
#                                                                max_depth=None,
#                                                                max_features='auto',
#                                                                max_leaf_nodes=None,
#                                                                max_samples=None,
#                                                                min_impurity_decrease=0.0,
#                                                                min_impurity_sp...
#                                                                min_samples_leaf=1,
#                                                                min_samples_split=2,
#                                                                min_weight_fraction_leaf=0.0,
#                                                                n_estimators=100,
#                                                                n_jobs=None,
#                                                                oob_score=False,
#                                                                random_state=None,
#                                                                verbose=0,
#                                                                warm_start=False))],
#                                 verbose=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'rf__max_depth': [2, 3, 4, 5],
#                          'rf__n_estimators': [50, 100, 150, 200]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)
# Best Hyperparameters: {'rf__max_depth': 5, 'rf__n_estimators': 150}
#
#
# Counter({1.0: 970, 0.0: 960})
# Accuracy: 0.6772020725388601
# [[543 206]
#  [417 764]]
#               precision    recall  f1-score   support
#
#          0.0       0.57      0.72      0.64       749
#          1.0       0.79      0.65      0.71      1181
#
#     accuracy                           0.68      1930
#    macro avg       0.68      0.69      0.67      1930
# weighted avg       0.70      0.68      0.68      1930

# %%
pickling_on = open("models/rf_cv_best.pickle","wb")
pickle.dump(rf_cv.best_estimator_, pickling_on)
pickling_on.close()

# %% [markdown]
# ### XGBoost

# %%
#Buy Signal
steps = [('scaler', StandardScaler()),
        ('xgb', XGBClassifier(learning_rate = 0.05, scale_pos_weight=5366/7438))]

pipeline = Pipeline(steps)
parameters = {'xgb__n_estimators':[50,100,150,200],
              'xgb__max_depth':[2,3,4,5]
              }

xgb_cv = GridSearchCV(pipeline, param_grid= parameters, cv=5)
xgb_cv.fit(X_train, y_train)
y_pred = xgb_cv.predict(X_test)

# Compute and print metrics
best_hyperparams = xgb_cv.best_params_
print(xgb_cv)
print('Best Hyperparameters:', best_hyperparams)
buy_accuracy = round(xgb_cv.score(X_test, y_test)*100, 2)
print("\n")
print(Counter(y_pred))
print("Accuracy: {}".format(xgb_cv.score(X_test, y_test)))
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# GridSearchCV(cv=5, error_score=nan,
#              estimator=Pipeline(memory=None,
#                                 steps=[('scaler',
#                                         StandardScaler(copy=True,
#                                                        with_mean=True,
#                                                        with_std=True)),
#                                        ('xgb',
#                                         XGBClassifier(base_score=None,
#                                                       booster=None,
#                                                       colsample_bylevel=None,
#                                                       colsample_bynode=None,
#                                                       colsample_bytree=None,
#                                                       gamma=None, gpu_id=None,
#                                                       importance_type='gain',
#                                                       interaction_constraints=None,
#                                                       learning_rate=0.05,
#                                                       m...
#                                                       random_state=None,
#                                                       reg_alpha=None,
#                                                       reg_lambda=None,
#                                                       scale_pos_weight=0.7214304920677601,
#                                                       subsample=None,
#                                                       tree_method=None,
#                                                       validate_parameters=False,
#                                                       verbosity=None))],
#                                 verbose=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'xgb__max_depth': [2, 3, 4, 5],
#                          'xgb__n_estimators': [50, 100, 150, 200]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)
# Best Hyperparameters: {'xgb__max_depth': 5, 'xgb__n_estimators': 200}
#
#
# Counter({1.0: 1086, 0.0: 844})
# Accuracy: 0.7487046632124352
# [[554 195]
#  [290 891]]
#               precision    recall  f1-score   support
#
#          0.0       0.66      0.74      0.70       749
#          1.0       0.82      0.75      0.79      1181
#
#     accuracy                           0.75      1930
#    macro avg       0.74      0.75      0.74      1930
# weighted avg       0.76      0.75      0.75      1930

# %%
pickling_on = open("models/xgb_cv_best.pickle","wb")
pickle.dump(xgb_cv.best_estimator_, pickling_on)
pickling_on.close()

# %% [markdown]
# ### Artificial Neural Network

# %%
tf.keras.backend.set_floatx('float64')

ann = keras.Sequential([
    keras.layers.Dense(units=24, activation='relu', input_shape= (X_test.shape[1],)),
    keras.layers.Dense(units=12, activation='relu'),
#    keras.layers.Dense(units=6, activation='relu'),
    keras.layers.Dense(units=6, activation='relu'),
    keras.layers.Dense(units=2, activation='softmax')
], )

ann.compile(optimizer='rmsprop',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=['accuracy'],
            )

callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=5)

history = ann.fit(X_train.values, y_train.values, 
    class_weight='balanced',
    callbacks=[callback],
    epochs=50, 
    validation_split=0.24
)

y_pred = np.argmax(ann.predict(X_test), axis=-1)
print(Counter(y_pred))
print("Accuracy:", accuracy_score(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Train on 4644 samples, validate on 1467 samples
# Epoch 1/50
# 4644/4644 [==============================] - 1s 282us/sample - loss: 0.7845 - accuracy: 0.5015 - val_loss: 0.7128 - val_accuracy: 0.5487
# Epoch 2/50
# 4644/4644 [==============================] - 1s 121us/sample - loss: 0.6915 - accuracy: 0.5500 - val_loss: 0.6791 - val_accuracy: 0.5767
# Epoch 3/50
# 4644/4644 [==============================] - 1s 116us/sample - loss: 0.6803 - accuracy: 0.5719 - val_loss: 0.6800 - val_accuracy: 0.5924
# Epoch 4/50
# 4644/4644 [==============================] - 1s 118us/sample - loss: 0.6774 - accuracy: 0.5801 - val_loss: 0.6815 - val_accuracy: 0.5753
# Epoch 5/50
# 4644/4644 [==============================] - 1s 120us/sample - loss: 0.6774 - accuracy: 0.5853 - val_loss: 0.6752 - val_accuracy: 0.5808
# Epoch 6/50
# 4644/4644 [==============================] - 1s 124us/sample - loss: 0.6753 - accuracy: 0.5816 - val_loss: 0.6797 - val_accuracy: 0.5924
# Epoch 7/50
# 4644/4644 [==============================] - 1s 122us/sample - loss: 0.6744 - accuracy: 0.5844 - val_loss: 0.6743 - val_accuracy: 0.5828
# Epoch 8/50
# 4644/4644 [==============================] - 1s 124us/sample - loss: 0.6728 - accuracy: 0.5851 - val_loss: 0.6709 - val_accuracy: 0.5890
# Epoch 9/50
# 4644/4644 [==============================] - 1s 127us/sample - loss: 0.6720 - accuracy: 0.5857 - val_loss: 0.6757 - val_accuracy: 0.5794
# Epoch 10/50
# 4644/4644 [==============================] - 1s 127us/sample - loss: 0.6720 - accuracy: 0.5915 - val_loss: 0.6829 - val_accuracy: 0.5603
# Epoch 11/50
# 4644/4644 [==============================] - 1s 135us/sample - loss: 0.6704 - accuracy: 0.5853 - val_loss: 0.6750 - val_accuracy: 0.5855
# Epoch 12/50
# 4644/4644 [==============================] - 1s 146us/sample - loss: 0.6679 - accuracy: 0.5915 - val_loss: 0.6776 - val_accuracy: 0.5842
# Epoch 13/50
# 4644/4644 [==============================] - 1s 135us/sample - loss: 0.6733 - accuracy: 0.5820 - val_loss: 0.6716 - val_accuracy: 0.6033
# Epoch 14/50
# 4644/4644 [==============================] - 1s 151us/sample - loss: 0.6689 - accuracy: 0.5902 - val_loss: 0.6714 - val_accuracy: 0.5917
# Epoch 15/50
# 4644/4644 [==============================] - 1s 152us/sample - loss: 0.6693 - accuracy: 0.5896 - val_loss: 0.6719 - val_accuracy: 0.5965
# Epoch 16/50
# 4644/4644 [==============================] - 1s 125us/sample - loss: 0.6677 - accuracy: 0.5881 - val_loss: 0.6753 - val_accuracy: 0.5985
# Epoch 17/50
# 4644/4644 [==============================] - 1s 122us/sample - loss: 0.6676 - accuracy: 0.5853 - val_loss: 0.6845 - val_accuracy: 0.5406
# Epoch 18/50
# 4644/4644 [==============================] - 1s 118us/sample - loss: 0.6669 - accuracy: 0.5863 - val_loss: 0.6737 - val_accuracy: 0.5985
# Epoch 19/50
# 4644/4644 [==============================] - 1s 136us/sample - loss: 0.6661 - accuracy: 0.5913 - val_loss: 0.6763 - val_accuracy: 0.5930
# Epoch 20/50
# 4644/4644 [==============================] - 1s 147us/sample - loss: 0.6671 - accuracy: 0.5879 - val_loss: 0.6762 - val_accuracy: 0.5924
# Epoch 21/50
# 4644/4644 [==============================] - 1s 142us/sample - loss: 0.6675 - accuracy: 0.5909 - val_loss: 0.6783 - val_accuracy: 0.5869
# Epoch 22/50
# 4644/4644 [==============================] - 1s 133us/sample - loss: 0.6667 - accuracy: 0.5913 - val_loss: 0.6737 - val_accuracy: 0.5999
# Epoch 23/50
# 4644/4644 [==============================] - 1s 131us/sample - loss: 0.6638 - accuracy: 0.5937 - val_loss: 0.6897 - val_accuracy: 0.5712
# Epoch 24/50
# 4644/4644 [==============================] - 1s 129us/sample - loss: 0.6663 - accuracy: 0.5960 - val_loss: 0.6747 - val_accuracy: 0.6012
# Epoch 25/50
# 4644/4644 [==============================] - 1s 127us/sample - loss: 0.6652 - accuracy: 0.5911 - val_loss: 0.6775 - val_accuracy: 0.5965
# Epoch 26/50
# 4644/4644 [==============================] - 1s 128us/sample - loss: 0.6634 - accuracy: 0.5969 - val_loss: 0.6794 - val_accuracy: 0.6005
# Epoch 27/50
# 4644/4644 [==============================] - 1s 131us/sample - loss: 0.6638 - accuracy: 0.5978 - val_loss: 0.6899 - val_accuracy: 0.5617
# Epoch 28/50
# 4644/4644 [==============================] - 1s 130us/sample - loss: 0.6647 - accuracy: 0.5965 - val_loss: 0.6722 - val_accuracy: 0.6074
# Epoch 29/50
# 4644/4644 [==============================] - 1s 130us/sample - loss: 0.6655 - accuracy: 0.5868 - val_loss: 0.6734 - val_accuracy: 0.6005
# Epoch 30/50
# 4644/4644 [==============================] - 1s 130us/sample - loss: 0.6625 - accuracy: 0.5973 - val_loss: 0.6876 - val_accuracy: 0.5753
# Epoch 31/50
# 4644/4644 [==============================] - ETA: 0s - loss: 0.6623 - accuracy: 0.59 - 1s 127us/sample - loss: 0.6639 - accuracy: 0.5954 - val_loss: 0.6751 - val_accuracy: 0.5978
# Epoch 32/50
# 4644/4644 [==============================] - 1s 130us/sample - loss: 0.6643 - accuracy: 0.5954 - val_loss: 0.6759 - val_accuracy: 0.5971
# Epoch 33/50
# 4644/4644 [==============================] - 1s 129us/sample - loss: 0.6628 - accuracy: 0.5930 - val_loss: 0.6910 - val_accuracy: 0.5685
# Epoch 34/50
# 4644/4644 [==============================] - 1s 135us/sample - loss: 0.6625 - accuracy: 0.5935 - val_loss: 0.6813 - val_accuracy: 0.5862
# Epoch 35/50
# 4644/4644 [==============================] - 1s 133us/sample - loss: 0.6639 - accuracy: 0.5907 - val_loss: 0.6787 - val_accuracy: 0.5992
# Epoch 36/50
# 4644/4644 [==============================] - 1s 132us/sample - loss: 0.6620 - accuracy: 0.5950 - val_loss: 0.6758 - val_accuracy: 0.5999
# Epoch 37/50
# 4644/4644 [==============================] - 1s 128us/sample - loss: 0.6626 - accuracy: 0.6014 - val_loss: 0.6734 - val_accuracy: 0.5985
# Epoch 38/50
# 4644/4644 [==============================] - 1s 130us/sample - loss: 0.6621 - accuracy: 0.5963 - val_loss: 0.6790 - val_accuracy: 0.6005
# Epoch 39/50
# 4644/4644 [==============================] - 1s 128us/sample - loss: 0.6606 - accuracy: 0.5975 - val_loss: 0.6743 - val_accuracy: 0.5951
# Epoch 40/50
# 4644/4644 [==============================] - 1s 129us/sample - loss: 0.6625 - accuracy: 0.5952 - val_loss: 0.6856 - val_accuracy: 0.5453
# Epoch 41/50
# 4644/4644 [==============================] - 1s 131us/sample - loss: 0.6625 - accuracy: 0.6001 - val_loss: 0.6801 - val_accuracy: 0.5794
# Epoch 42/50
# 4644/4644 [==============================] - 1s 128us/sample - loss: 0.6613 - accuracy: 0.6023 - val_loss: 0.6771 - val_accuracy: 0.5985
# Epoch 43/50
# 4644/4644 [==============================] - 1s 129us/sample - loss: 0.6614 - accuracy: 0.6051 - val_loss: 0.6776 - val_accuracy: 0.6060
# Epoch 44/50
# 4644/4644 [==============================] - 1s 129us/sample - loss: 0.6587 - accuracy: 0.6025 - val_loss: 0.6834 - val_accuracy: 0.5869
# Epoch 45/50
# 4644/4644 [==============================] - 1s 137us/sample - loss: 0.6614 - accuracy: 0.6001 - val_loss: 0.6829 - val_accuracy: 0.5876
# Epoch 46/50
# 4644/4644 [==============================] - 1s 128us/sample - loss: 0.6609 - accuracy: 0.6040 - val_loss: 0.6794 - val_accuracy: 0.5896
# Epoch 47/50
# 4644/4644 [==============================] - 1s 131us/sample - loss: 0.6593 - accuracy: 0.6027 - val_loss: 0.6853 - val_accuracy: 0.5801
# Epoch 48/50
# 4644/4644 [==============================] - 1s 130us/sample - loss: 0.6608 - accuracy: 0.5993 - val_loss: 0.6823 - val_accuracy: 0.5978
# Epoch 49/50
# 4644/4644 [==============================] - 1s 134us/sample - loss: 0.6603 - accuracy: 0.5997 - val_loss: 0.6848 - val_accuracy: 0.5603
# Counter({1: 1359, 0: 571})
# Accuracy: 0.572020725388601
# [[247 502]
#  [324 857]]
#               precision    recall  f1-score   support
#
#          0.0       0.43      0.33      0.37       749
#          1.0       0.63      0.73      0.67      1181
#
#     accuracy                           0.57      1930
#    macro avg       0.53      0.53      0.52      1930
# weighted avg       0.55      0.57      0.56      1930

# %%
ann.save('models/ann.h5')

# %%
X_test.columns
# Out:
# Index(['Returns', 'Unemployment Rate', 'Inflation Rate', 'Misery Index',
#        'local_price', 'Bullish', 'Neutral', 'Bearish', 'Bull-Bear Spread',
#        'EMA12_pctchg', 'RSI', 'Pct_Chg', 'MACD_sentiment', 'Upper_BB_pctchg',
#        'Lower_BB_pctchg', 'EMA_sentiment', 'Volume_sentiment'],
#       dtype='object')
